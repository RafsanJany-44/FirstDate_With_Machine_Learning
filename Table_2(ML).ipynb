# %% [markdown]
# <a href="https://colab.research.google.com/github/RafsanJany-44/FirstDate_With_Machine_Learning/blob/main/Table_2(ML).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #<font color='coral'>How Machine Learning Works</font>

# %% [markdown]
# ![Untitled Page.png](data:image/png;base64,...)

# %% [markdown]
# #<font color='coral'>Lets Imagine a Story</font>

# %% [markdown]
# ![maxresdefault.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# |Celsius|Fahrenheit|
# |---|---|
# |90|194\.0|
# |45|113\.0|
# |-25|-13\.0|
# |130|266\.0|
# |35|95\.0|
# |29|84\.2|
# |-30|-22\.0|
# |27|80\.6|
# |56|132\.8|
# |3|37\.4|
# |212|413\.6|
# |121|249\.8|
# |180|356\.0|
# |-40|-40\.0|

# %%
cel_data = [90,45,-25,130,35,29,-30,27,56,3,212,121,180,-40,-35]

# %%
far_data = [194.0, 113.0, -13.0, 266.0, 95.0, 84.2, -22.0, 80.6, 132.8, 37.4, 413.6, 249.8, 356.0, -40.0, -31.0]

# %% [markdown]
# **Making A DataFrame**

# %%
import numpy as np
import pandas as pd


data = {
    "Celsius":cel_data,
    "Fahrenheit":far_data
}
df = pd.DataFrame(data)

# %%
from sklearn.linear_model import LinearRegression
X = df["Celsius"].values.reshape(-1, 1)
Y = df["Fahrenheit"].values.reshape(-1, 1)
reg = LinearRegression().fit(X, Y)

# %%
m = reg.coef_[0]
c = reg.intercept_

# %%
print("Slop:",m)
print("Intercept:",c)
# Out:
# Slop: [1.8]
# Intercept: [32.]

# %% [markdown]
# #Lets check

# %%
x = 18


y = m*x + c

print(y)
# Out:
# [64.4]
